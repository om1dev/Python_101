# %%
x = int(input("Enter a number: "))
y = int(input("Enter another number: "))
print(x + y)
# Out:
# 110

# %%
vari1 = "Hello Bhai"
vari2 = 404
vari3 = 3.14

ls = ["Sunny", "wheather", "404", "Error", 500, "Float", 3.14, "True", False, "None"]

dict0 = {"Name" : "Om Dhage", "Age" : 20, "State" : "Maharastra", "Occupation" : "Student"}

print(vari1)
print(vari2)
print(vari3)
print(ls)
print(dict0)
print(dict0["Name"] + " is Best Developer in the world")
# Out:
# Hello Bhai
# 404
# 3.14
# ['Sunny', 'wheather', '404', 'Error', 500, 'Float', 3.14, 'True', False, 'None']
# {'Name': 'Om Dhage', 'Age': 20, 'State': 'Maharastra', 'Occupation': 'Student'}
# Om Dhage is Best Developer in the world
