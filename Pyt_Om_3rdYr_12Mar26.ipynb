# %%
sales_data = ["1800", "1200", "900", "1150", "2560", "1890", "2200"]
sales_data = [int(sale) for sale in sales_data]
for i in sales_data:
	print(f"Day{sales_data.index(i)+1} sales : Rs {i}")
	
total_sales = sum(sales_data)
print(f"Total sales for the week: Rs {total_sales}")
# Out:
# Day1 sales : Rs 1800
# Day2 sales : Rs 1200
# Day3 sales : Rs 900
# Day4 sales : Rs 1150
# Day5 sales : Rs 2560
# Day6 sales : Rs 1890
# Day7 sales : Rs 2200
# Total sales for the week: Rs 11700
